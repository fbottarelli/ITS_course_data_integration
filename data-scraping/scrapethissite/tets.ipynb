# %%
# !pip install requests beautifulsoup4 requests

# %%
import requests

url = 'https://www.scrapethissite.com/pages/simple/'
response = requests.get(url)

# Verifica che la richiesta sia andata a buon fine
if response.status_code == 200:
    html_content = response.text
else:
    print("Errore nella richiesta:", response.status_code)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_content, 'html.parser')

# %% [markdown]
# ogni paese è racchiuso in un div con la classe country, e le informazioni specifiche sono all'interno di questo div

# %%
countries = soup.find_all('div', class_='country')

for country in countries:
    name = country.find('h3', class_='country-name').text.strip()
    capital = country.find('span', class_='country-capital').text.strip()
    population = country.find('span', class_='country-population').text.strip()
    area = country.find('span', class_='country-area').text.strip()
    
    print(f"Paese: {name}, Capitale: {capital}, Popolazione: {population}, Area: {area} km²")
# Out:
# Paese: Andorra, Capitale: Andorra la Vella, Popolazione: 84000, Area: 468.0 km²
# Paese: United Arab Emirates, Capitale: Abu Dhabi, Popolazione: 4975593, Area: 82880.0 km²
# Paese: Afghanistan, Capitale: Kabul, Popolazione: 29121286, Area: 647500.0 km²
# Paese: Antigua and Barbuda, Capitale: St. John's, Popolazione: 86754, Area: 443.0 km²
# Paese: Anguilla, Capitale: The Valley, Popolazione: 13254, Area: 102.0 km²
# Paese: Albania, Capitale: Tirana, Popolazione: 2986952, Area: 28748.0 km²
# Paese: Armenia, Capitale: Yerevan, Popolazione: 2968000, Area: 29800.0 km²
# Paese: Angola, Capitale: Luanda, Popolazione: 13068161, Area: 1246700.0 km²
# Paese: Antarctica, Capitale: None, Popolazione: 0, Area: 1.4E7 km²
# Paese: Argentina, Capitale: Buenos Aires, Popolazione: 41343201, Area: 2766890.0 km²
# Paese: American Samoa, Capitale: Pago Pago, Popolazione: 57881, Area: 199.0 km²
# Paese: Austria, Capitale: Vienna, Popolazione: 8205000, Area: 83858.0 km²
# ...
